# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
train=pd.read_csv("G:\AV\Dataset\loan-prediction train.csv")
train.shape
train["Loan_Status"].value_counts()
train["Loan_Status"].value_counts(normalize=True)
train["Loan_Status"].value_counts(normalize=True).plot.bar()

# %%
plt.figure(1)
plt.subplot(221)
train["Gender"].value_counts(normalize=True).plot.bar(figsize=(20,10), title="Gender")

# %%
train["Married"].value_counts(normalize=True).plot.bar(figsize=(20,10), title="Married")

# %%
train["Self_Employed"].value_counts(normalize=True).plot.bar(figsize=(20,10), title="Self_Employed")

# %%
train["Credit_History"].value_counts(normalize=True).plot.bar(figsize=(20,10), title="Credit_History")

# %%
plt.show()

# %%
train["Dependents"].value_counts(normalize=True).plot.bar(figsize=(20,10), title="Dependents")

# %%
train["Education"].value_counts(normalize=True).plot.bar(figsize=(20,10), title="Education")

# %%
train["Property_Area"].value_counts(normalize=True).plot.bar(figsize=(20,10), title="Property_Area")

# %%
plt.figure(1)
plt.subplot(221)
sb.distplot(train.ApplicantIncome)
# Out:
# C:\Users\Ankit Bhatia\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Ankit Bhatia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sb.boxplot(train.ApplicantIncome)

# %%
train.boxplot(column="ApplicantIncome", by="Education")

# %%
sb.distplot(train.CoapplicantIncome)
# Out:
# C:\Users\Ankit Bhatia\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Ankit Bhatia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sb.boxplot(train.CoapplicantIncome)

# %%
test=train=pd.read_csv("G:\AV\Dataset\loan-prediction test.csv")
test.shape
# Out:
# (367, 12)

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df=train.dropna()
sb.distplot(df["LoanAmount"])
# Out:
# C:\Users\Ankit Bhatia\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Ankit Bhatia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sb.boxplot(df["LoanAmount"])

# %% [markdown]
# ### bivariate analysis

# %%
train=pd.read_csv("G:\AV\Dataset\loan-prediction train.csv")
train.shape
Gender=pd.crosstab(train["Gender"], train["Loan_Status"],normalize=True).plot.bar()

# %%
pd.crosstab(train["Education"], train["Loan_Status"],normalize=True).plot.bar()

# %%
pd.crosstab(train["Married"],train["Loan_Status"],normalize=True).plot.bar()

# %%
pd.crosstab(train["Self_Employed"],train["Loan_Status"],normalize=True).plot.bar()

# %%
pd.crosstab(train["Dependents"], train["Loan_Status"],normalize=True).plot.bar(stacked=True)

# %%
Property_Area=pd.crosstab(train["Property_Area"], train["Loan_Status"],normalize=True)
Property_Area.sum(1) #sum along columns
# Out:
# Property_Area
# Rural        0.291531
# Semiurban    0.379479
# Urban        0.328990
# dtype: float64

# %%
Property_Area
Property_Area.div(Property_Area.sum(1), axis=0).plot(kind="bar", stacked=True)

# %%
train.groupby('Loan_Status')["ApplicantIncome"].mean().plot(kind="bar")

# %% [markdown]
# ## ?????bins=[1000,2500,3500,5500,7000]

# %%
bins=[0,1000.2000,3000,4000,5000,6000,7000,8000,10000]
group=['Low','Average','High', 'Very high']

# %%
# x=pd.cut(df['ApplicantIncome'],bins=bins, labels=group)

# %%
sb.distplot(df['ApplicantIncome'],bins=bins, hist=True)
sb.barplot(x)
# Out:
# C:\Users\Ankit Bhatia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Ankit Bhatia\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-221-9ee797c9417c> in <module>()
#       1 sb.distplot(df['ApplicantIncome'],bins=bins, hist=True)
# ----> 2 sb.barplot(x)
#
# ...

# %%
x.value_counts(normalize=True)
x.groupby(x.value_counts())

# %%
x.value_counts(normalize=True).plot(kind="bar")
x
# Out:
# 0           High
# 1        Average
# 2           High
# 4        Average
# 5            Low
# 6            Low
# 7        Average
# 9            Low
# 10       Average
# 14          High
# 15          High
# 16          High
# 17       Average
# 18           NaN
# 19           Low
# 20           Low
# 21           Low
# 23       Average
# 24          High
# 25           NaN
# 27     Very high
# 29       Average
# 30           Low
# 31     Very high
# 32       Average
# 33       Average
# 34       Average
# 35       Average
# 37           Low
# 38          High
#          ...
# 332      Average
# 333         High
# 334          Low
# 335          Low
# 337          Low
# 338          Low
# 339         High
# 340      Average
# 341      Average
# 342      Average
# 343         High
# 344    Very high
# 345          NaN
# 346      Average
# 347      Average
# 348      Average
# 349          Low
# 350          NaN
# 352         High
# 353         High
# 354         High
# ...
